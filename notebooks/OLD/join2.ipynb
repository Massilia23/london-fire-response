# %% [markdown]
#  <span style="color:#42a5f5; font-size:2em; font-weight:bold;">Jointure des données d'incidents et de mobilisations</span>

# %% [markdown]
#  <span style="font-weight:bold">Ce notebook à pour but d'explorer et de réaliser une jointureentre les données de  mobilisations et d'incidents !</span>

# %% [markdown]
# <span style="color:#e91e63; font-size:1em; font-weight:bold;"> 1. Import des données précedemment chargées et nettoyées</span>

# %%
#import des BU
import pandas as pd
import warnings
# Supprimer les warnings pour une meilleure lisibilité
warnings.filterwarnings("ignore")

# %%
# Chargement des fichiers nettoyés
df_incidents = pd.read_csv("../../data/raw/Cleaned_data/InUSE/cleaned_data_incidents.csv", dtype={"IncidentNumber": str}, low_memory=False)
df_mobilisations = pd.read_csv("../../data/raw/Cleaned_data/InUSE/cleaned_data_mobilisations.csv", dtype={"IncidentNumber": str}, low_memory=False)

# %%
# 🔧 Nettoyage de la colonne IncidentNumber
def clean_incident_number(value):
    if pd.isna(value):
        return None
    value = str(value)
    if '.' in value:
        return value.split('.')[0]
    if '-' in value:
        return value.split('-')[0]
    return value

df_incidents["IncidentNumber_clean"] = df_incidents["IncidentNumber"].apply(clean_incident_number)
df_mobilisations["IncidentNumber_clean"] = df_mobilisations["IncidentNumber"].apply(clean_incident_number)

# %%
# 📑 Colonnes à conserver pour les mobilisations
mobilisations_cols_to_keep = [
    "IncidentNumber_clean", "CalYear", "BoroughName", "WardName", "HourOfCall",
    "DateAndTimeMobilised", "DateAndTimeMobile", "DateAndTimeArrived",
    "TurnoutTimeSeconds", "TravelTimeSeconds", "AttendanceTimeSeconds",
    "DeployedFromStation_Name", "DeployedFromLocation"
]

df_mobilisations_reduced = df_mobilisations[mobilisations_cols_to_keep].copy()

# %%
# Jointure complète avec indicateur
df_merge = df_incidents.merge(
    df_mobilisations,
    how="outer",
    on="IncidentNumber_clean",
    suffixes=("_incident", "_mobilisation"),
    indicator=True
)

# %%
# Séparer les cas :
df_jointure = df_merge[df_merge["_merge"] == "both"].copy()
df_left_only = df_merge[df_merge["_merge"] == "left_only"].copy()
df_right_only = df_merge[df_merge["_merge"] == "right_only"].copy()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Séparer les cas :
# ----> 2 df_jointure = df_merge[df_merge["_merge"] == "both"].copy()
#       3 df_left_only = df_merge[df_merge["_merge"] == "left_only"].copy()
#       4 df_right_only = df_merge[df_merge["_merge"] == "right_only"].copy()
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\generic.py:6811, in NDFrame.copy(self, deep)
#    6662 @final
#    6663 def copy(self, deep: bool_t | None = True) -> Self:
#    6664     """
#    6665     Make a copy of this object's indices and data.
#    6666
#    (...)   6809     dtype: int64
#    6810     """
# -> 6811     data = self._mgr.copy(deep=deep)
#    6812     self._clear_item_cache()
#    6813     return self._constructor_from_mgr(data, axes=data.axes).__finalize__(
#    6814         self, method="copy"
#    6815     )
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\internals\managers.py:604, in BaseBlockManager.copy(self, deep)
#     601         res._blklocs = self._blklocs.copy()
#     603 if deep:
# --> 604     res._consolidate_inplace()
#     605 return res
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\internals\managers.py:1788, in BlockManager._consolidate_inplace(self)
#    1782 def _consolidate_inplace(self) -> None:
#    1783     # In general, _consolidate_inplace should only be called via
#    1784     #  DataFrame._consolidate_inplace, otherwise we will fail to invalidate
#    1785     #  the DataFrame's _item_cache. The exception is for newly-created
#    1786     #  BlockManager objects not yet attached to a DataFrame.
#    1787     if not self.is_consolidated():
# -> 1788         self.blocks = _consolidate(self.blocks)
#    1789         self._is_consolidated = True
#    1790         self._known_consolidated = True
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\internals\managers.py:2269, in _consolidate(blocks)
#    2267 new_blocks: list[Block] = []
#    2268 for (_can_consolidate, dtype), group_blocks in grouper:
# -> 2269     merged_blocks, _ = _merge_blocks(
#    2270         list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    2271     )
#    2272     new_blocks = extend_blocks(merged_blocks, new_blocks)
#    2273 return tuple(new_blocks)
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\internals\managers.py:2300, in _merge_blocks(blocks, dtype, can_consolidate)
#    2297     bvals2 = cast(Sequence[NDArrayBackedExtensionArray], bvals)
#    2298     new_values = bvals2[0]._concat_same_type(bvals2, axis=0)
# -> 2300 argsort = np.argsort(new_mgr_locs)
#    2301 new_values = new_values[argsort]
#    2302 new_mgr_locs = new_mgr_locs[argsort]
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:1243, in argsort(a, axis, kind, order, stable)
#    1130 @array_function_dispatch(_argsort_dispatcher)
#    1131 def argsort(a, axis=-1, kind=None, order=None, *, stable=None):
#    1132     """
#    1133     Returns the indices that would sort an array.
#    1134
#    (...)   1241
#    1242     """
# -> 1243     return _wrapfunc(
#    1244         a, 'argsort', axis=axis, kind=kind, order=order, stable=stable
#    1245     )
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)     64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
# Sauvegardes
output_path = "../../data/processed/"
df_jointure.to_csv(f"{output_path}df_jointure_incidents_mobilisations.csv", index=False)
df_left_only.to_csv(f"{output_path}df_incidents_without_mobilisations.csv", index=False)
df_right_only.to_csv(f"{output_path}df_mobilisations_without_incidents.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Sauvegardes
#       2 output_path = "../../data/processed/"
# ----> 3 df_jointure.to_csv(f"{output_path}df_jointure_incidents_mobilisations.csv", index=False)
#       4 df_left_only.to_csv(f"{output_path}df_incidents_without_mobilisations.csv", index=False)
#       5 df_right_only.to_csv(f"{output_path}df_mobilisations_without_incidents.csv", index=False)
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)   3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)   1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)    267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '..\..\data\processed'

# %%
# Résumés
print(f"Jointure réussie : {df_jointure.shape[0]} lignes")
print(f"Incidents sans mobilisation : {df_left_only.shape[0]} lignes")
print(f"Mobilisations sans incident : {df_right_only.shape[0]} lignes")
# Out:
# Jointure réussie : 9949296 lignes
# Incidents sans mobilisation : 78266 lignes
# Mobilisations sans incident : 2426 lignes

# %%
#  Aperçus
print("\nAperçu jointure :")
display(df_jointure.head())

print("\nIncidents sans mobilisation :")
display(df_left_only.head())

print("\n Mobilisations sans incident :")
display(df_right_only.head())
# Out:
# 🧭 Aperçu jointure :
#   IncidentNumber_incident  DateOfCall  CalYear_incident TimeOfCall  \
# 0         000001-01012016  2016-01-01            2016.0   00:03:17
# 1         000001-01012016  2016-01-01            2016.0   00:03:17
# 2         000001-01012016  2016-01-01            2016.0   00:03:17
# 3         000001-01012016  2016-01-01            2016.0   00:03:17
# 4         000001-01012016  2016-01-01            2016.0   00:03:17
#
#    HourOfCall_incident IncidentGroup        StopCodeDescription  \
# 0                  0.0   False Alarm  False alarm - Good intent
# 1                  0.0   False Alarm  False alarm - Good intent
# 2                  0.0   False Alarm  False alarm - Good intent
# 3                  0.0   False Alarm  False alarm - Good intent
# 4                  0.0   False Alarm  False alarm - Good intent
#
#   SpecialServiceType PropertyCategory               PropertyType  ...  \
# 0                NaN         Dwelling  House - single occupancy   ...
# 1                NaN         Dwelling  House - single occupancy   ...
# 2                NaN         Dwelling  House - single occupancy   ...
# 3                NaN         Dwelling  House - single occupancy   ...
# 4                NaN         Dwelling  House - single occupancy   ...
#
#   DateAndTimeReturned DeployedFromStation_Code DeployedFromStation_Name  \
# 0                 NaN                      E25                Plumstead
# 1                 NaN                      A24                     Soho
# 2                 NaN                      G38                   Heston
# 3                 NaN                      G38                   Heston
# 4                 NaN                      G24                 Southall
#
#    DeployedFromLocation  PumpOrder PlusCode_Code  PlusCode_Description  \
# 0          Home Station        1.0       Initial  Initial Mobilisation
# 1          Home Station        1.0       Initial  Initial Mobilisation
# 2          Home Station        2.0       Initial  Initial Mobilisation
# 3          Home Station        1.0       Initial  Initial Mobilisation
# 4          Home Station        3.0       Initial  Initial Mobilisation
#
#   DelayCodeId               DelayCode_Description _merge
# 0         NaN                                 NaN   both
# 1         9.0             Traffic, roadworks, etc   both
# 2         7.0  Arrived but held up - Other reason   both
# 3         7.0  Arrived but held up - Other reason   both
# 4         NaN                                 NaN   both
#
# [5 rows x 65 columns]
# 📉 Incidents sans mobilisation :
#         IncidentNumber_incident  DateOfCall  CalYear_incident TimeOfCall  \
# 272257          004605-12012021  2021-01-12            2021.0   12:52:12
# 272258          004605-10012023  2023-01-10            2023.0   18:09:44
# 410424          006932-17012018  2018-01-17            2018.0   15:54:10
# 2207215         037464-16032022  2022-03-16            2022.0   14:44:29
# 2207216         037464-05032025  2025-03-05            2025.0   12:04:11
#
#          HourOfCall_incident    IncidentGroup StopCodeDescription  \
# 272257                  12.0  Special Service     Special Service
# 272258                  18.0  Special Service     Special Service
# 410424                  15.0  Special Service     Special Service
# 2207215                 14.0             Fire        Primary Fire
# 2207216                 12.0  Special Service     Special Service
#
#         SpecialServiceType   PropertyCategory  \
# 272257        Lift Release           Dwelling
# 272258        Lift Release    Non Residential
# 410424        Lift Release    Non Residential
# 2207215                NaN       Road Vehicle
# 2207216       Lift Release  Other Residential
#
#                                               PropertyType  ...  \
# 272257   Purpose Built Flats/Maisonettes - 10 or more s...  ...
# 272258                                    Shopping Centre   ...
# 410424                               Purpose built office   ...
# 2207215                                         Lorry/HGV   ...
# 2207216                        Retirement/Old Persons Home  ...
#
#         DateAndTimeReturned DeployedFromStation_Code DeployedFromStation_Name  \
# 272257                  NaN                      NaN                      NaN
# 272258                  NaN                      NaN                      NaN
# 410424                  NaN                      NaN                      NaN
# 2207215                 NaN                      NaN                      NaN
# 2207216                 NaN                      NaN                      NaN
#
#          DeployedFromLocation  PumpOrder PlusCode_Code PlusCode_Description  \
# 272257                    NaN        NaN           NaN                  NaN
# 272258                    NaN        NaN           NaN                  NaN
# 410424                    NaN        NaN           NaN                  NaN
# 2207215                   NaN        NaN           NaN                  NaN
# 2207216                   NaN        NaN           NaN                  NaN
#
#         DelayCodeId DelayCode_Description     _merge
# 272257          NaN                   NaN  left_only
# 272258          NaN                   NaN  left_only
# 410424          NaN                   NaN  left_only
# 2207215         NaN                   NaN  left_only
# 2207216         NaN                   NaN  left_only
#
# [5 rows x 65 columns]
# 📈 Mobilisations sans incident :
#         IncidentNumber_incident DateOfCall  CalYear_incident TimeOfCall  \
# 3151292                     NaN        NaN               NaN        NaN
# 3725945                     NaN        NaN               NaN        NaN
# 3827852                     NaN        NaN               NaN        NaN
# 3827853                     NaN        NaN               NaN        NaN
# 3840219                     NaN        NaN               NaN        NaN
#
#          HourOfCall_incident IncidentGroup StopCodeDescription  \
# 3151292                  NaN           NaN                 NaN
# 3725945                  NaN           NaN                 NaN
# 3827852                  NaN           NaN                 NaN
# 3827853                  NaN           NaN                 NaN
# 3840219                  NaN           NaN                 NaN
#
#         SpecialServiceType PropertyCategory PropertyType  ...  \
# 3151292                NaN              NaN          NaN  ...
# 3725945                NaN              NaN          NaN  ...
# 3827852                NaN              NaN          NaN  ...
# 3827853                NaN              NaN          NaN  ...
# 3840219                NaN              NaN          NaN  ...
#
#         DateAndTimeReturned DeployedFromStation_Code DeployedFromStation_Name  \
# 3151292                 NaN                      A35                  Enfield
# 3725945                 NaN                      H37               Wallington
# 3827852                 NaN                      G27         North Kensington
# 3827853                 NaN                      ESX                    Essex
# 3840219                 NaN                      G31                 Northolt
#
#          DeployedFromLocation  PumpOrder PlusCode_Code  PlusCode_Description  \
# 3151292          Home Station        1.0       Initial  Initial Mobilisation
# 3725945          Home Station        1.0       Initial  Initial Mobilisation
# 3827852          Home Station        1.0       Initial  Initial Mobilisation
# 3827853         Other Station        1.0       Initial  Initial Mobilisation
# 3840219          Home Station        1.0       Initial  Initial Mobilisation
#
#         DelayCodeId               DelayCode_Description      _merge
# 3151292         NaN                                 NaN  right_only
# 3725945         NaN                                 NaN  right_only
# 3827852        12.0                         Not held up  right_only
# 3827853         NaN                                 NaN  right_only
# 3840219         7.0  Arrived but held up - Other reason  right_only
#
# [5 rows x 65 columns]
