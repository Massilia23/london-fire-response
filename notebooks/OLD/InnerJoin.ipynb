# %% [markdown]
#  <span style="color:#42a5f5; font-size:2em; font-weight:bold;">Jointure des données d'incidents et de mobilisations</span>

# %% [markdown]
#  <span style="font-weight:bold">Ce notebook à pour but d'explorer et de réaliser une jointureentre les données de  mobilisations et d'incidents !</span>

# %% [markdown]
# <span style="color:#e91e63; font-size:1em; font-weight:bold;"> 1. Import des données précedemment chargées et nettoyées</span>

# %%
#import des BU
import pandas as pd
import warnings
# Supprimer les warnings pour une meilleure lisibilité
warnings.filterwarnings("ignore")

# %%
# Chargement des fichiers nettoyés
df_incidents = pd.read_csv("../../data/raw/Cleaned_data/InUSE/cleaned_data_incidents.csv", dtype={"IncidentNumber": str}, low_memory=False)
df_mobilisations = pd.read_csv("../../data/raw/Cleaned_data/InUSE/cleaned_data_mobilisations.csv", dtype={"IncidentNumber": str}, low_memory=False)

# %%
#Fonction de nettoyage
def clean_incident_number(val):
    """Nettoyage d’un numéro d’incident :
    - suppression après un point (ex: 205600101.00 → 205600101)
    - suppression après un tiret (ex: 000004-01012025 → 000004)
    - suppression des zéros en tête (optionnel)
    """
    if pd.isna(val):
        return None
    val = str(val).strip()
    if '.' in val:
        val = val.split('.')[0]
    if '-' in val:
        val = val.split('-')[0]
    return val.lstrip('0')  # Retire les zéros en tête pour harmoniser

# Nettoyage de la cl& de jointure
df_incidents["IncidentNumber_clean"] = df_incidents["IncidentNumber"].apply(clean_incident_number)
df_mobilisations["IncidentNumber_clean"] = df_mobilisations["IncidentNumber"].apply(clean_incident_number)

# %%
#Vérification du chargement  et nettoyage clé
print("Données incidents clean chargées:")
display(df_incidents)
# Out:
# Données incidents clean chargées:
#           IncidentNumber  DateOfCall  CalYear TimeOfCall  HourOfCall  \
# 0           235138081.00  2009-01-01     2009   00:00:37           0
# 1                1091.00  2009-01-01     2009   00:00:46           0
# 2                2091.00  2009-01-01     2009   00:03:00           0
# 3                3091.00  2009-01-01     2009   00:04:27           0
# 4                5091.00  2009-01-01     2009   00:05:39           0
# ...                  ...         ...      ...        ...         ...
# 1824968  054201-31032025  2025-03-31     2025   23:39:44          23
# 1824969  054203-31032025  2025-03-31     2025   23:40:09          23
# 1824970  054204-31032025  2025-03-31     2025   23:42:16          23
# 1824971  054205-31032025  2025-03-31     2025   23:42:42          23
# 1824972  054211-31032025  2025-03-31     2025   23:54:57          23
#
#            IncidentGroup StopCodeDescription     SpecialServiceType  \
# ...

# %%
#Vérification du chargement et nettoyage clé
print("Données mobilisations clean chargées:")
display(df_mobilisations)
# Out:
# Données mobilisations clean chargées:
#           IncidentNumber  CalYear             BoroughName  \
# 0        000004-01012025     2025  HAMMERSMITH AND FULHAM
# 1        000004-01012025     2025  HAMMERSMITH AND FULHAM
# 2        000005-01012025     2025                  MERTON
# 3        000006-01012025     2025                 CROYDON
# 4        000007-01012025     2025                  BARNET
# ...                  ...      ...                     ...
# 2578271  221555-30122024     2024    KINGSTON UPON THAMES
# 2578272  221556-30122024     2024               ISLINGTON
# 2578273  221556-30122024     2024               ISLINGTON
# 2578274  221557-30122024     2024  KENSINGTON AND CHELSEA
# 2578275  221558-30122024     2024                LEWISHAM
#
#                           WardName  HourOfCall  ResourceMobilisationId  \
# 0                     FULHAM REACH           0                 6862256
# 1                     FULHAM REACH           0                 6862257
# ...

# %%
#Vérifier la période des données d'incidents et de mobilisation: doit etre de 2009 à 2025
print("Période des données d'incidents chargées: De", min(df_incidents["CalYear"]), "à", max(df_incidents["CalYear"]))
print("Période des données de mobilisations chargées: De", min(df_mobilisations["CalYear"]), "à", max(df_mobilisations["CalYear"]))
# Out:
# Période des données d'incidents chargées: De 2009 à 2025
# Période des données de mobilisations chargées: De 2009 à 2025

# %% [markdown]
# Comme précedemment explorer : Un incident peut avoir plusieurs mobilisations et une mobilisation à un seul incident ==> Inner join
# 1 824 973(incidents)              X            2 578 276(mobilisations)

# %%
print("Vérification taille:")
print("Incidents :", len(df_incidents), " | Mobilisations :", len(df_mobilisations))
# Out:
# Vérification taille:
# Incidents : 1824973  | Mobilisations : 2578276

# %%
#Analyse  avant jointure
print("Incidents - Clés uniques :", df_incidents["IncidentNumber_clean"].nunique())
print("Mobilisations - Clés uniques :", df_mobilisations["IncidentNumber_clean"].nunique())

print("\nVérification doublons dans incidents :", df_incidents["IncidentNumber_clean"].duplicated().sum())
print("Vérification doublons dans mobilisations :", df_mobilisations["IncidentNumber_clean"].duplicated().sum())

print("\nNAs dans incidents :", df_incidents["IncidentNumber_clean"].isna().sum())
print("NAs dans mobilisations :", df_mobilisations["IncidentNumber_clean"].isna().sum())
# Out:
# Incidents - IDs uniques : 982931
# Mobilisations - IDs uniques : 907153
#
# Vérification doublons dans incidents : 842042
# Vérification doublons dans mobilisations : 1671123
#
# NAs dans incidents : 0
# NAs dans mobilisations : 0

# %%
print("Type IncidentNumber :", df_incidents["IncidentNumber"].dtype)
print("Type IncidentNumber :", df_mobilisations["IncidentNumber"].dtype)
print("Type IncidentNumber :", df_incidents["IncidentNumber_clean"].dtype)
print("Type IncidentNumber :", df_mobilisations["IncidentNumber_clean"].dtype)
# Out:
# Type IncidentNumber : object
# Type IncidentNumber : object
# Type IncidentNumber : object
# Type IncidentNumber : object

# %%
# Étape 1 : Lister les colonnes des deux DataFrames
cols_incidents = set(df_incidents.columns)
cols_mobilisations = set(df_mobilisations.columns)

# Étape 2 : Trouver les colonnes communes
common_columns = cols_incidents.intersection(cols_mobilisations)

# Étape 3 : Afficher
print("Colonnes présentes dans les deux DataFrames (possibles doublons après jointure) :")
for col_name in sorted(common_columns):
    print(f"- {col_name}")

print(f"\nNombre de colonnes communes : {len(common_columns)}")
# Out:
# Colonnes présentes dans les deux DataFrames (possibles doublons après jointure) :
# - CalYear
# - HourOfCall
# - IncidentNumber
# - IncidentNumber_clean
#
# Nombre de colonnes communes : 4

# %%
# INNER join
df_inner = df_incidents.merge(
    df_mobilisations,
    how="inner",
    on="IncidentNumber_clean",
    suffixes=("_incident", "_mobilisation")
)

print(f"\nJointure INNER : {df_inner.shape[0]} lignes")
# Out:
# Jointure INNER : 9962884 lignes

# %%
# Export
df_inner.to_csv("../../data/df_jointure_inner.csv", index=False)
print(f"\n INNER JOIN terminée : {df_inner.shape[0]} lignes")
# Out:
#  INNER JOIN terminée : 9962884 lignes

# %%
# % de jointure réussie par rapport à la table mobilisations
joined_ratio = len(df_inner) / len(df_mobilisations)
print(f"Taux de jointure réussie : {joined_ratio:.2%}")
# Out:
# Taux de jointure réussie : 386.42%

# %%
mobilisations_per_incident = df_mobilisations["IncidentNumber_clean"].value_counts()
print("Nb moyen de mobilisations par incident :", mobilisations_per_incident.mean())
print("Nb max de mobilisations pour un incident :", mobilisations_per_incident.max())
# Out:
# Nb moyen de mobilisations par incident : 2.842162237241127
# Nb max de mobilisations pour un incident : 61

# %% [markdown]
# Moyenne : 2,84 mobilisations / incident
# Cela confirme que chaque incident génère en moyenne près de 3 mobilisations différentes (engins, camions, unités…).
# Maximum : 61 mobilisations pour un seul incident
# Cela explique pourquoi on obtient les différences dans les colonnes comme CalYear ou HourOfCall :
# ➜ l’incident apparaît répété 61 fois dans df_joined si on ne contrôles pas bien la jointure !

# %%
print(df_inner.columns)
print("Types de données après jointure :")
for col in df_inner.columns:
    print(f"{col}: {df_inner[col].dtype}")
# Out:
# Index(['IncidentNumber_incident', 'DateOfCall', 'CalYear_incident',
#        'TimeOfCall', 'HourOfCall_incident', 'IncidentGroup',
#        'StopCodeDescription', 'SpecialServiceType', 'PropertyCategory',
#        'PropertyType', 'AddressQualifier', 'Postcode_full',
#        'Postcode_district', 'UPRN', 'USRN', 'IncGeo_BoroughCode',
#        'IncGeo_BoroughName', 'ProperCase', 'IncGeo_WardCode',
#        'IncGeo_WardName', 'IncGeo_WardNameNew', 'Easting_m', 'Northing_m',
#        'Easting_rounded', 'Northing_rounded', 'Latitude', 'Longitude', 'FRS',
#        'IncidentStationGround', 'FirstPumpArriving_AttendanceTime',
#        'FirstPumpArriving_DeployedFromStation',
#        'SecondPumpArriving_AttendanceTime',
#        'SecondPumpArriving_DeployedFromStation',
#        'NumStationsWithPumpsAttending', 'NumPumpsAttending', 'PumpCount',
#        'PumpMinutesRounded', 'NotionalCost', 'NumCalls',
#        'IncidentNumber_clean', 'IncidentNumber_mobilisation',
# ...

# %%
# Doublons dans la jointure
dups_jointure = df_inner["IncidentNumber_clean"].duplicated().sum()
print(f"\nDoublons dans la jointure (IDs répétés) : {dups_jointure}")

# Vérification des colonnes critiques
print("\nColonnes critiques manquantes :")
print(df_inner[["IncidentNumber_clean", "DateAndTimeArrived", "AttendanceTimeSeconds"]].isna().sum())
# Out:
# Doublons dans la jointure (IDs répétés) : 9057878
#
# Colonnes critiques manquantes :
# IncidentNumber_clean           0
# DateAndTimeArrived       3622896
# AttendanceTimeSeconds          0
# dtype: int64

# %%
# Vérifier que toutes les années sont bien dans la plage attendue
print("Années uniques :", sorted(df_joined["CalYear"].unique()))

# Ou afficher celles qui ne sont pas entre 2009 et 2025
invalid_years = df_joined[~df_joined["CalYear"].between(2009, 2025)]
print("Nombre d'années hors intervalle 2009–2025 :", len(invalid_years))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # Vérifier que toutes les années sont bien dans la plage attendue
# ----> 2 print("Années uniques :", sorted(df_joined["CalYear"].unique()))
#       4 # Ou afficher celles qui ne sont pas entre 2009 et 2025
#       5 invalid_years = df_joined[~df_joined["CalYear"].between(2009, 2025)]
#
# NameError: name 'df_joined' is not defined

# %%
# Séparer les cas :
df_inner = df_merge[df_merge["_merge"] == "both"].copy()
df_left_only = df_merge[df_merge["_merge"] == "left_only"].copy()
df_right_only = df_merge[df_merge["_merge"] == "right_only"].copy()
# Out:
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[13], line 2
#
#       1 # Séparer les cas :
#
# ----> 2 df_jointure = df_merge[df_merge["_merge"] == "both"].copy()
#
#       3 df_left_only = df_merge[df_merge["_merge"] == "left_only"].copy()
#
#       4 df_right_only = df_merge[df_merge["_merge"] == "right_only"].copy()
#
#
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\generic.py:6811, in NDFrame.copy(self, deep)
#
#    6662 @final
#
#    6663 def copy(self, deep: bool_t | None = True) -> Self:
#
#    6664     """
#
#    6665     Make a copy of this object's indices and data.
#
#    6666
#
#    (...)   6809     dtype: int64
#
#    6810     """
#
# -> 6811     data = self._mgr.copy(deep=deep)
#
#    6812     self._clear_item_cache()
#
#    6813     return self._constructor_from_mgr(data, axes=data.axes).__finalize__(
#
# ...

# %%
# Résumés
print(f"Jointure réussie : {df_inner.shape[0]} lignes")
print(f"Incidents sans mobilisation : {df_left_only.shape[0]} lignes")
print(f"Mobilisations sans incident : {df_right_only.shape[0]} lignes")
# Out:
# Jointure réussie : 9962884 lignes
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 # Résumés
#       2 print(f"Jointure réussie : {df_inner.shape[0]} lignes")
# ----> 3 print(f"Incidents sans mobilisation : {df_left_only.shape[0]} lignes")
#       4 print(f"Mobilisations sans incident : {df_right_only.shape[0]} lignes")
#
# NameError: name 'df_left_only' is not defined

# %%
#  Aperçus
print("\nAperçu jointure :")
display(df_inner.head())

print("\nIncidents sans mobilisation :")
display(df_left_only.head())

print("\n Mobilisations sans incident :")
display(df_right_only.head())
# Out:
# Aperçu jointure :
#   IncidentNumber_incident  DateOfCall  CalYear_incident TimeOfCall  \
# 0            235138081.00  2009-01-01              2009   00:00:37
# 1            235138081.00  2009-01-01              2009   00:00:37
# 2                 1091.00  2009-01-01              2009   00:00:46
# 3                 1091.00  2009-01-01              2009   00:00:46
# 4                 1091.00  2009-01-01              2009   00:00:46
#
#    HourOfCall_incident    IncidentGroup StopCodeDescription  \
# 0                    0  Special Service     Special Service
# 1                    0  Special Service     Special Service
# 2                    0  Special Service     Special Service
# 3                    0  Special Service     Special Service
# 4                    0  Special Service     Special Service
#
#       SpecialServiceType PropertyCategory          PropertyType  ...  \
# 0                    RTC     Road Vehicle                  Car   ...
# ...

# %%
# Sauvegardes
output_path = "../../data/processed/"
df_inner.to_csv(f"{output_path}df_jointure_incidents_mobilisations.csv", index=False)
df_left_only.to_csv(f"{output_path}df_incidents_without_mobilisations.csv", index=False)
df_right_only.to_csv(f"{output_path}df_mobilisations_without_incidents.csv", index=False)
