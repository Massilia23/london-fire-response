# %% [markdown]
#  <span style="color:#42a5f5; font-size:2em; font-weight:bold;">Jointure des données d'incidents et de mobilisations</span>

# %% [markdown]
#  <span style="font-weight:bold">Ce notebook à pour but d'explorer et de réaliser une jointureentre les données de  mobilisations et d'incidents !</span>

# %% [markdown]
# <span style="color:#e91e63; font-size:1em; font-weight:bold;"> 1. Import des données précedemment chargées et nettoyées</span>

# %%
#import des BU
import pandas as pd

# %%
# Chargement des fichiers CSV
df_incidents = pd.read_csv("../../data/raw/Cleaned_data/InUSE/cleaned_data_incidents.csv")
df_mobilisations = pd.read_csv("../../data/raw/Cleaned_data/InUSE/cleaned_data_mobilisations.csv")
# Out:
# C:\Users\9609241C\AppData\Local\Temp\ipykernel_2888\2508286040.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_incidents = pd.read_csv("../../data/raw/Cleaned_data/InUSE/cleaned_data_incidents.csv")
# C:\Users\9609241C\AppData\Local\Temp\ipykernel_2888\2508286040.py:3: DtypeWarning: Columns (0,2,3,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_mobilisations = pd.read_csv("../../data/raw/Cleaned_data/InUSE/cleaned_data_mobilisations.csv")

# %%
#Vérification du chargement
print("Données incidents clean chargées:")
display(df_incidents)
# Out:
# Données incidents clean chargées:
#           IncidentNumber  DateOfCall  CalYear TimeOfCall  HourOfCall  \
# 0            235138081.0  2009-01-01     2009   00:00:37           0
# 1                 1091.0  2009-01-01     2009   00:00:46           0
# 2                 2091.0  2009-01-01     2009   00:03:00           0
# 3                 3091.0  2009-01-01     2009   00:04:27           0
# 4                 5091.0  2009-01-01     2009   00:05:39           0
# ...                  ...         ...      ...        ...         ...
# 1824968  054201-31032025  2025-03-31     2025   23:39:44          23
# 1824969  054203-31032025  2025-03-31     2025   23:40:09          23
# 1824970  054204-31032025  2025-03-31     2025   23:42:16          23
# 1824971  054205-31032025  2025-03-31     2025   23:42:42          23
# 1824972  054211-31032025  2025-03-31     2025   23:54:57          23
#
#            IncidentGroup StopCodeDescription     SpecialServiceType  \
# 0        Special Service     Special Service                    RTC
# 1        Special Service     Special Service  Assist other agencies
# 2                   Fire      Secondary Fire                    NaN
# 3                   Fire      Secondary Fire                    NaN
# 4                   Fire      Secondary Fire                    NaN
# ...                  ...                 ...                    ...
# 1824968      False Alarm                 AFA                    NaN
# 1824969  Special Service     Special Service               Flooding
# 1824970  Special Service     Special Service   Effecting entry/exit
# 1824971             Fire      Secondary Fire                    NaN
# 1824972             Fire        Primary Fire                    NaN
#
#         PropertyCategory                                       PropertyType  \
# 0           Road Vehicle                                               Car
# 1                Outdoor                               Lake/pond/reservoir
# 2                Outdoor                             Road surface/pavement
# 3                Outdoor        Domestic garden (vegetation not equipment)
# 4                Outdoor              Cycle path/public footpath/bridleway
# ...                  ...                                                ...
# 1824968  Non Residential                                   Shopping Centre
# 1824969         Dwelling  Purpose Built Flats/Maisonettes - 4 to 9 storeys
# 1824970         Dwelling  Licensed House in Multiple Occupation - Up to ...
# 1824971          Outdoor                                      Loose refuse
# 1824972  Non Residential                              Purpose built office
#
#          ... FirstPumpArriving_AttendanceTime  \
# 0        ...                            319.0
# 1        ...                              NaN
# 2        ...                            308.0
# 3        ...                            210.0
# 4        ...                            233.0
# ...      ...                              ...
# 1824968  ...                            264.0
# 1824969  ...                            229.0
# 1824970  ...                            373.0
# 1824971  ...                            367.0
# 1824972  ...                            384.0
#
#         FirstPumpArriving_DeployedFromStation  \
# 0                                   Battersea
# 1                                         NaN
# 2                                    Edmonton
# 3                                  Hillingdon
# 4                                    Holloway
# ...                                       ...
# 1824968                           Hammersmith
# 1824969                              Holloway
# 1824970                                Harrow
# 1824971                              East Ham
# 1824972                                Heston
#
#         SecondPumpArriving_AttendanceTime  \
# 0                                   342.0
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                   250.0
# ...                                   ...
# 1824968                             247.0
# 1824969                               NaN
# 1824970                               NaN
# 1824971                             412.0
# 1824972                             390.0
#
#          SecondPumpArriving_DeployedFromStation  \
# 0                                       Clapham
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                      Holloway
# ...                                         ...
# 1824968                             Hammersmith
# 1824969                                     NaN
# 1824970                                     NaN
# 1824971                               Stratford
# 1824972                                  Heston
#
#          NumStationsWithPumpsAttending NumPumpsAttending PumpCount  \
# 0                                  2.0               2.0         2
# 1                                  NaN               NaN         1
# 2                                  1.0               1.0         1
# 3                                  1.0               1.0         1
# 4                                  1.0               2.0         2
# ...                                ...               ...       ...
# 1824968                            2.0               3.0         3
# 1824969                            1.0               1.0         1
# 1824970                            1.0               1.0         1
# 1824971                            2.0               2.0         2
# 1824972                            2.0               3.0         3
#
#         PumpMinutesRounded NotionalCost NumCalls
# 0                       60          255      1.0
# 1                       60          255      1.0
# 2                       60          255      2.0
# 3                       60          255      2.0
# 4                       60          255      1.0
# ...                    ...          ...      ...
# 1824968                 60          430      2.0
# 1824969                 60          430      1.0
# 1824970                 60          430      1.0
# 1824971                 60          430      2.0
# 1824972                 60          430      1.0
#
# [1824973 rows x 39 columns]

# %%
#Vérification du chargement
print("Données mobilisations clean chargées:")
display(df_mobilisations)
# Out:
# Données mobilisations clean chargées:
#           IncidentNumber  CalYear             BoroughName  \
# 0        000004-01012025     2025  HAMMERSMITH AND FULHAM
# 1        000004-01012025     2025  HAMMERSMITH AND FULHAM
# 2        000005-01012025     2025                  MERTON
# 3        000006-01012025     2025                 CROYDON
# 4        000007-01012025     2025                  BARNET
# ...                  ...      ...                     ...
# 2578271  221555-30122024     2024    KINGSTON UPON THAMES
# 2578272  221556-30122024     2024               ISLINGTON
# 2578273  221556-30122024     2024               ISLINGTON
# 2578274  221557-30122024     2024  KENSINGTON AND CHELSEA
# 2578275  221558-30122024     2024                LEWISHAM
#
#                           WardName  HourOfCall  ResourceMobilisationId  \
# 0                     FULHAM REACH           0                 6862256
# 1                     FULHAM REACH           0                 6862257
# 2                      WEST BARNES           0                 6862259
# 3        PURLEY OAKS & RIDDLESDOWN           0                 6862260
# 4                        BURNT OAK           0                 6862261
# ...                            ...         ...                     ...
# 2578271                COOMBE VALE          23                 6861269
# 2578272              FINSBURY PARK          23                 6861270
# 2578273              FINSBURY PARK          23                 6861271
# 2578274             ROYAL HOSPITAL          23                 6861272
# 2578275                   LADYWELL          23                 6861273
#
#         Resource_Code PerformanceReporting DateAndTimeMobilised  \
# 0                H331                    2  2025-01-01 00:02:00
# 1                G261                    1  2025-01-01 00:02:00
# 2                H401                    1  2025-01-01 00:03:00
# 3                H291                    1  2025-01-01 00:04:00
# 4                G222                    1  2025-01-01 00:05:00
# ...               ...                  ...                  ...
# 2578271          H391                    2  2024-12-30 23:47:00
# 2578272          A311                    1  2024-12-30 23:48:00
# 2578273          F321                    2  2024-12-30 23:48:00
# 2578274          G341                    1  2024-12-30 23:59:00
# 2578275          E211                    1  2024-12-30 23:59:00
#
#            DateAndTimeMobile  ...      DateAndTimeLeft  DateAndTimeReturned  \
# 0        2025-01-01 00:07:00  ...  2025-01-01 00:23:00                  NaN
# 1        2025-01-01 00:02:00  ...  2025-01-01 00:38:00                  NaN
# 2        2025-01-01 00:04:00  ...  2025-01-01 00:11:00                  NaN
# 3        2025-01-01 00:06:00  ...  2025-01-01 00:25:00                  NaN
# 4        2025-01-01 00:06:00  ...  2025-01-01 00:27:00                  NaN
# ...                      ...  ...                  ...                  ...
# 2578271  2024-12-30 23:49:00  ...  2024-12-30 23:56:00                  NaN
# 2578272  2024-12-30 23:49:00  ...  2024-12-31 00:16:00                  NaN
# 2578273  2024-12-30 23:49:00  ...  2024-12-31 00:04:00                  NaN
# 2578274  2024-12-31 00:01:00  ...  2024-12-31 00:39:00                  NaN
# 2578275  2024-12-31 00:01:00  ...  2024-12-31 00:29:00                  NaN
#
#          DeployedFromStation_Code  DeployedFromStation_Name  \
# 0                             H33                Wandsworth
# 1                             G36               Hammersmith
# 2                             H40                New Malden
# 3                             H29                    Purley
# 4                             G22                  Stanmore
# ...                           ...                       ...
# 2578271                       H39                  Surbiton
# 2578272                       A31                  Holloway
# 2578273                       F32           Stoke Newington
# 2578274                       G34                   Chelsea
# 2578275                       E21                  Lewisham
#
#         DeployedFromLocation PumpOrder PlusCode_Code  PlusCode_Description  \
# 0               Home Station         2       Initial  Initial Mobilisation
# 1              Other Station         1       Initial  Initial Mobilisation
# 2               Home Station         1       Initial  Initial Mobilisation
# 3               Home Station         1       Initial  Initial Mobilisation
# 4               Home Station         1       Initial  Initial Mobilisation
# ...                      ...       ...           ...                   ...
# 2578271         Home Station         2       Initial  Initial Mobilisation
# 2578272         Home Station         1       Initial  Initial Mobilisation
# 2578273         Home Station         2       Initial  Initial Mobilisation
# 2578274         Home Station         1       Initial  Initial Mobilisation
# 2578275         Home Station         1       Initial  Initial Mobilisation
#
#         DelayCodeId    DelayCode_Description
# 0              12.0              Not held up
# 1              12.0              Not held up
# 2               NaN                      NaN
# 3               NaN                      NaN
# 4               NaN                      NaN
# ...             ...                      ...
# 2578271         9.0  Traffic, roadworks, etc
# 2578272         NaN                      NaN
# 2578273        12.0              Not held up
# 2578274         NaN                      NaN
# 2578275         NaN                      NaN
#
# [2578276 rows x 24 columns]

# %%
#Vérifier la période des données d'incidents et de mobilisation: doit etre de 2009 à 2025
print("Période des données d'incidents chargées: De", min(df_incidents["CalYear"]), "à", max(df_incidents["CalYear"]))
print("Période des données de mobilisations chargées: De", min(df_mobilisations["CalYear"]), "à", max(df_mobilisations["CalYear"]))
# Out:
# Période des données d'incidents chargées: De 2009 à 2025
# Période des données de mobilisations chargées: De 2009 à 2025

# %% [markdown]
#  <span style="color:#e91e63; font-size:1em; font-weight:bold;"> 2. test et jointure</span>

# %% [markdown]
# Comme précedemment explorer : Un incident peut avoir plusieurs mobilisations et une mobilisation à un seul incident ==> Inner join
#
#                                     1 824 973(incidents)              X            2 578 276(mobilisations)

# %%
print("Vérification taille:")
print("Incidents :", len(df_incidents), " | Mobilisations :", len(df_mobilisations))
# Out:
# Vérification taille:
# Incidents : 1824973  | Mobilisations : 2578276

# %%
# Colonnes à garder pour la table mobilisations
mobilisations_cols_to_keep = [
    'IncidentNumber', 'CalYear', 'BoroughName', 'WardName', 'HourOfCall',
    'DateAndTimeMobilised', 'DateAndTimeMobile', 'DateAndTimeArrived',
    'TurnoutTimeSeconds', 'TravelTimeSeconds', 'AttendanceTimeSeconds',
    'DeployedFromStation_Name', 'DeployedFromLocation'
]

# Garde uniquement ces colonnes dans df_mobilisations
df_mobilisations_reduced = df_mobilisations[mobilisations_cols_to_keep].copy()

# %%
#  Prétraitement de la colonne IncidentNumber 
#meme si déjà forcé lors du chargement en  type string !

def clean_incident_number(value):
    """Nettoyage de l'identifiant d'incident"""
    if pd.isna(value):
        return None
    value = str(value)
    if '.' in value:
        return value.split('.')[0]
    elif '-' in value:
        return value.split('-')[0]
    return value

print("Type IncidentNumber :", df_incidents["IncidentNumber"].dtype)
print("Type IncidentNumber :", df_mobilisations["IncidentNumber"].dtype)
# Out:
# Type IncidentNumber : object
# Type IncidentNumber : object

# %%
# Application du dtype aux deux jeux de données au cas ou :
df_incidents["incident_id_cleaned"] = df_incidents["IncidentNumber"].apply(clean_incident_number)
df_mobilisations["incident_id_cleaned"] = df_mobilisations["IncidentNumber"].apply(clean_incident_number)

print("Type IncidentNumber Incidents:", df_incidents["IncidentNumber"].dtype)
print("Type IncidentNumber Mobilisations:", df_mobilisations["IncidentNumber"].dtype)
# Out:
# Type IncidentNumber Incidents: object
# Type IncidentNumber Mobilisations: object

# %%
# Jointure sur la colonne nettoyée 
df_joined = pd.merge(df_mobilisations, df_incidents, on="incident_id_cleaned", how="inner")

# Count après jointure
print("Count après jointure (INNER JOIN sur incident_id_cleaned) :", len(df_joined))

# % de jointure réussie par rapport à la table mobilisations
joined_ratio = len(df_joined) / len(df_mobilisations)
print(f"Taux de jointure réussie : {joined_ratio:.2%}")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Jointure sur la colonne nettoyée
# ----> 2 df_joined = pd.merge(df_mobilisations, df_incidents, on="incident_id_cleaned", how="inner")
#       4 # Count après jointure
#       5 print("Count après jointure (INNER JOIN sur incident_id_cleaned) :", len(df_joined))
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\reshape\merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)    167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
#     180         suffixes=suffixes,
#     181         indicator=indicator,
#     182         validate=validate,
#     183     )
#     184     return op.get_result(copy=copy)
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\reshape\merge.py:800, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     797     self.left = self.left._drop_labels_or_levels(left_drop)
#     799 if right_drop:
# --> 800     self.right = self.right._drop_labels_or_levels(right_drop)
#     802 self._maybe_require_matching_dtypes(self.left_join_keys, self.right_join_keys)
#     803 self._validate_tolerance(self.left_join_keys)
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\generic.py:1989, in NDFrame._drop_labels_or_levels(self, keys, axis)
#    1987     # Handle dropping columns labels
#    1988     if labels_to_drop:
# -> 1989         dropped.drop(labels_to_drop, axis=1, inplace=True)
#    1990 else:
#    1991     # Handle dropping column levels
#    1992     if levels_to_drop:
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\generic.py:4869, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4866     new_axis = axis.take(indexer)
#    4868 bm_axis = self.ndim - axis_num - 1
# -> 4869 new_mgr = self._mgr.reindex_indexer(
#    4870     new_axis,
#    4871     indexer,
#    4872     axis=bm_axis,
#    4873     allow_dups=True,
#    4874     copy=None,
#    4875     only_slice=only_slice,
#    4876 )
#    4877 result = self._constructor_from_mgr(new_mgr, axes=new_mgr.axes)
#    4878 if self.ndim == 1:
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\internals\managers.py:680, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     677     raise IndexError("Requested axis not found in manager")
#     679 if axis == 0:
# --> 680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#     687     new_blocks = [
#     688         blk.take_nd(
#     689             indexer,
#    (...)    695         for blk in self.blocks
#     696     ]
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\internals\managers.py:843, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy, ref_inplace_op)
#     841                     blocks.append(nb)
#     842             else:
# --> 843                 nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     844                 blocks.append(nb)
#     846 return blocks
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\internals\blocks.py:1307, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1304     allow_fill = True
#    1306 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1307 new_values = algos.take_nd(
#    1308     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1309 )
#    1311 # Called from three places in managers, all of which satisfy
#    1312 #  these assertions
#    1313 if isinstance(self, ExtensionBlock):
#    1314     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1315     #  algos.take_nd call above.
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pandas\core\array_algos\take.py:157, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     155     out = np.empty(out_shape, dtype=dtype, order="F")
#     156 else:
# --> 157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
#     162 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 292. MiB for an array with shape (21, 1824973) and data type object

# %%
#Vérifier  aprés jointure de la période des données d'incidents et de mobilisation: doit etre de 2009 à 2025
print("Période des données d'incidents joint à mobilisation chargées: De", min(df_joined["CalYear"]), "à", max(df_joined["CalYear"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 #Vérifier  aprés jointure de la période des données d'incidents et de mobilisation: doit etre de 2009 à 2025
# ----> 2 print("Période des données d'incidents joint à mobilisation chargées: De", min(df_joined["CalYear"]), "à", max(df_joined["CalYear"]))
#
# NameError: name 'df_joined' is not defined

# %% [markdown]
# vu comment ma RAM est insufisante go pyspark!

# %%
from pyspark.sql import SparkSession

# Stop any existing Spark session (important si redémarré en cours de route)
try:
    spark.stop()
except:
    pass

# Démarrage d'une nouvelle session Spark
spark = SparkSession.builder \
    .appName("Test Spark Session") \
    .master("local[*]") \
    .getOrCreate()

print(spark.version)
# Out:
# 4.0.0

# %%
# 1. Import des bibliothèques & démarrage Spark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, split, when, min as spark_min, max as spark_max
from pyspark.sql.functions import col, when, regexp_extract

# Initialisation de la session Spark
spark = SparkSession.builder \
    .appName("Jointure Incidents & Mobilisations") \
    .master("local[*]") \
    .getOrCreate()

print("SparkSession initialisée")

# 2. Chargement des fichiers nettoyés
path_incidents = "../../data/raw/Cleaned_data/InUSE/cleaned_data_incidents.csv"
path_mobilisations = "../../data/raw/Cleaned_data/InUSE/cleaned_data_mobilisations.csv"

# Optionnel : Vérifie si les fichiers existent (Python natif)
import os
assert os.path.exists(path_incidents), f"Fichier introuvable : {path_incidents}"
assert os.path.exists(path_mobilisations), f"Fichier introuvable : {path_mobilisations}"

# Chargement CSV
df_incidents = spark.read.option("header", True).csv(path_incidents, inferSchema=True)
df_mobilisations = spark.read.option("header", True).csv(path_mobilisations, inferSchema=True)

print("Données chargées")

# 3. Aperçu rapide
print("Échantillon incidents")
(df_incidents.show(3))
print("Échantillon mobilisations")
df_mobilisations.show(3)

# 4. Vérification de la période des données
print("Période des incidents :")
df_incidents.select(spark_min("CalYear"), spark_max("CalYear")).show()

print("Période des mobilisations :")
df_mobilisations.select(spark_min("CalYear"), spark_max("CalYear")).show()

# 5. Sélection des colonnes pertinentes
#cols_to_keep = ['IncidentNumber', 'CalYear', 'BoroughName', 'WardName', 'HourOfCall','DateAndTimeMobilised', 'DateAndTimeMobile', 'DateAndTimeArrived','TurnoutTimeSeconds', 'TravelTimeSeconds', 'AttendanceTimeSeconds','DeployedFromStation_Name', 'DeployedFromLocation']
#df_mobilisations = df_mobilisations.select(*cols_to_keep)

# 6.Renommer la colonne "CalYear" pour éviter l'ambiguïté
df_incidents_cleaned = df_incidents_cleaned.withColumnRenamed("CalYear", "CalYear_inc")
# Out:
# SparkSession initialisée
# Données chargées
# Échantillon incidents
# +--------------+----------+-------+-------------------+----------+---------------+-------------------+--------------------+----------------+--------------------+--------------------+-------------+-----------------+----+----+------------------+------------------+----------+---------------+--------------------+--------------------+---------+----------+---------------+----------------+-----------+------------+------+---------------------+--------------------------------+-------------------------------------+---------------------------------+--------------------------------------+-----------------------------+-----------------+---------+------------------+------------+--------+
# |IncidentNumber|DateOfCall|CalYear|         TimeOfCall|HourOfCall|  IncidentGroup|StopCodeDescription|  SpecialServiceType|PropertyCategory|        PropertyType|    AddressQualifier|Postcode_full|Postcode_district|UPRN|USRN|IncGeo_BoroughCode|IncGeo_BoroughName|ProperCase|IncGeo_WardCode|     IncGeo_WardName|  IncGeo_WardNameNew|Easting_m|Northing_m|Easting_rounded|Northing_rounded|   Latitude|   Longitude|   FRS|IncidentStationGround|FirstPumpArriving_AttendanceTime|FirstPumpArriving_DeployedFromStation|SecondPumpArriving_AttendanceTime|SecondPumpArriving_DeployedFromStation|NumStationsWithPumpsAttending|NumPumpsAttending|PumpCount|PumpMinutesRounded|NotionalCost|NumCalls|
# +--------------+----------+-------+-------------------+----------+---------------+-------------------+--------------------+----------------+--------------------+--------------------+-------------+-----------------+----+----+------------------+------------------+----------+---------------+--------------------+--------------------+---------+----------+---------------+----------------+-----------+------------+------+---------------------+--------------------------------+-------------------------------------+---------------------------------+--------------------------------------+-----------------------------+-----------------+---------+------------------+------------+--------+
# |  235138081.00|2009-01-01|   2009|2025-06-12 00:00:37|         0|Special Service|    Special Service|                 RTC|    Road Vehicle|                Car |In street close t...|     SW11 4LB|             SW11| nan| nan|         E09000032|        WANDSWORTH|Wandsworth|      E05014010|      Battersea Park|      Battersea Park|   528652|    176830|         528650|          176850|51.47581173|-0.148894436|London|            Battersea|                             319|                            Battersea|                              342|                               Clapham|                            2|                2|        2|                60|         255|       1|
# |       1091.00|2009-01-01|   2009|2025-06-12 00:00:46|         0|Special Service|    Special Service|Assist other agen...|         Outdoor|Lake/pond/reservoir |Open land/water -...|      SE1 7SG|              SE1| nan| nan|         E09000022|           LAMBETH|   Lambeth|      E05014118|Waterloo & South ...|Waterloo & South ...|   530485|    179007|         530450|          179050|51.49495659| -0.12171203|London|              Lambeth|                            NULL|                                 NULL|                             NULL|                                  NULL|                         NULL|             NULL|        1|                60|         255|       1|
# |       2091.00|2009-01-01|   2009|2025-06-12 00:03:00|         0|           Fire|     Secondary Fire|                NULL|         Outdoor|Road surface/pave...|In street outside...|       N9 9EL|               N9| nan| nan|         E09000010|           ENFIELD|   Enfield|      E05013682|           Haselbury|           Haselbury|   533773|    194492|         533750|          194450|51.63334229|-0.068487965|London|             Edmonton|                             308|                             Edmonton|                             NULL|                                  NULL|                            1|                1|        1|                60|         255|       2|
# +--------------+----------+-------+-------------------+----------+---------------+-------------------+--------------------+----------------+--------------------+--------------------+-------------+-----------------+----+----+------------------+------------------+----------+---------------+--------------------+--------------------+---------+----------+---------------+----------------+-----------+------------+------+---------------------+--------------------------------+-------------------------------------+---------------------------------+--------------------------------------+-----------------------------+-----------------+---------+------------------+------------+--------+
# only showing top 3 rows
# Échantillon mobilisations
# +---------------+-------+--------------------+------------+----------+----------------------+-------------+--------------------+--------------------+-------------------+-------------------+------------------+-----------------+---------------------+-------------------+-------------------+------------------------+------------------------+--------------------+---------+-------------+--------------------+-----------+---------------------+
# | IncidentNumber|CalYear|         BoroughName|    WardName|HourOfCall|ResourceMobilisationId|Resource_Code|PerformanceReporting|DateAndTimeMobilised|  DateAndTimeMobile| DateAndTimeArrived|TurnoutTimeSeconds|TravelTimeSeconds|AttendanceTimeSeconds|    DateAndTimeLeft|DateAndTimeReturned|DeployedFromStation_Code|DeployedFromStation_Name|DeployedFromLocation|PumpOrder|PlusCode_Code|PlusCode_Description|DelayCodeId|DelayCode_Description|
# +---------------+-------+--------------------+------------+----------+----------------------+-------------+--------------------+--------------------+-------------------+-------------------+------------------+-----------------+---------------------+-------------------+-------------------+------------------------+------------------------+--------------------+---------+-------------+--------------------+-----------+---------------------+
# |000004-01012025|   2025|HAMMERSMITH AND F...|FULHAM REACH|         0|               6862256|         H331|                   2| 2025-01-01 00:02:00|2025-01-01 00:07:00|2025-01-01 00:13:00|               310|              311|                  621|2025-01-01 00:23:00|               NULL|                     H33|              Wandsworth|        Home Station|        2|      Initial|Initial Mobilisation|         12|          Not held up|
# |000004-01012025|   2025|HAMMERSMITH AND F...|FULHAM REACH|         0|               6862257|         G261|                   1| 2025-01-01 00:02:00|2025-01-01 00:02:00|2025-01-01 00:12:00|                11|              552|                  563|2025-01-01 00:38:00|               NULL|                     G36|             Hammersmith|       Other Station|        1|      Initial|Initial Mobilisation|         12|          Not held up|
# |000005-01012025|   2025|              MERTON| WEST BARNES|         0|               6862259|         H401|                   1| 2025-01-01 00:03:00|2025-01-01 00:04:00|2025-01-01 00:06:00|                33|              135|                  168|2025-01-01 00:11:00|               NULL|                     H40|              New Malden|        Home Station|        1|      Initial|Initial Mobilisation|       NULL|                 NULL|
# +---------------+-------+--------------------+------------+----------+----------------------+-------------+--------------------+--------------------+-------------------+-------------------+------------------+-----------------+---------------------+-------------------+-------------------+------------------------+------------------------+--------------------+---------+-------------+--------------------+-----------+---------------------+
# only showing top 3 rows
# Période des incidents :
# +------------+------------+
# |min(CalYear)|max(CalYear)|
# +------------+------------+
# |        2009|        2025|
# +------------+------------+
#
# Période des mobilisations :
# +------------+------------+
# |min(CalYear)|max(CalYear)|
# +------------+------------+
# |        2009|        2025|
# +------------+------------+

# %%
#Nettoyage IncidentNumber 
def clean_incident_number(col_):
    return when(col_.contains('.'),
    regexp_extract(col_, r"^([^\.]+)", 1)) \
    .when(col_.contains('-'),
    regexp_extract(col_, r"^([^-]+)", 1)) \
    .otherwise(col_)

df_incidents_cleaned = df_incidents.withColumn(
    "incident_id_cleaned", clean_incident_number(col("IncidentNumber"))
)

df_mobilisations_cleaned = df_mobilisations.withColumn(
    "incident_id_cleaned", clean_incident_number(col("IncidentNumber"))
)

# Jointure sur la colonne  id nettoyée 
df_joined = df_mobilisations_cleaned.join(
    df_incidents_cleaned,
    on="incident_id_cleaned",
    how="inner"
)

# 9. Statistiques de jointure
nb_incidents = df_incidents.count()
nb_mobilisations = df_mobilisations.count()
nb_jointure = df_joined.count()

print(f"Nombre d'incidents : {nb_incidents:,}")
print(f"Nombre de mobilisations : {nb_mobilisations:,}")
print(f"Lignes jointes : {nb_jointure:,}")
print(f"Taux de jointure réussie : {nb_jointure / nb_mobilisations:.2%}")
print(f"Taux de jointure réussie : {nb_jointure / nb_incidents:.2%}")
# Out:
# Nombre d'incidents : 1,824,973
# Nombre de mobilisations : 2,578,276
# Lignes jointes : 9,949,296
# Taux de jointure réussie : 385.89%
# Taux de jointure réussie : 545.17%

# %%
df_mobilisations_unmatched = df_mobilisations_cleaned.join(
    df_incidents_cleaned,
    on="incident_id_cleaned",
    how="left_anti"
)
print(f"Mobilisations non jointes : {df_mobilisations_unmatched.count():}")
# Out:
# Mobilisations non jointes : 2426

# %%
# Affichage des 10 premières lignes après jointure
print("Aperçu des données après jointure :")
df_joined.show(20, truncate=False)
# Out:
# Aperçu des données après jointure :
# +-------------------+---------------+-------+-----------+-----------+----------+----------------------+-------------+--------------------+--------------------+-------------------+-------------------+------------------+-----------------+---------------------+-------------------+-------------------+------------------------+------------------------+--------------------+---------+-------------+--------------------+-----------+---------------------+---------------+----------+-------+-------------------+----------+---------------+-------------------+-------------------------------+-----------------+-------------------------------------------------+------------------------------------+-------------+-----------------+-------------+----------+------------------+--------------------+--------------------+---------------+-----------------+------------------+---------+----------+---------------+----------------+-----------+------------+------+---------------------+--------------------------------+-------------------------------------+---------------------------------+--------------------------------------+-----------------------------+-----------------+---------+------------------+------------+--------+
# |incident_id_cleaned|IncidentNumber |CalYear|BoroughName|WardName   |HourOfCall|ResourceMobilisationId|Resource_Code|PerformanceReporting|DateAndTimeMobilised|DateAndTimeMobile  |DateAndTimeArrived |TurnoutTimeSeconds|TravelTimeSeconds|AttendanceTimeSeconds|DateAndTimeLeft    |DateAndTimeReturned|DeployedFromStation_Code|DeployedFromStation_Name|DeployedFromLocation|PumpOrder|PlusCode_Code|PlusCode_Description|DelayCodeId|DelayCode_Description|IncidentNumber |DateOfCall|CalYear|TimeOfCall         |HourOfCall|IncidentGroup  |StopCodeDescription|SpecialServiceType             |PropertyCategory |PropertyType                                     |AddressQualifier                    |Postcode_full|Postcode_district|UPRN         |USRN      |IncGeo_BoroughCode|IncGeo_BoroughName  |ProperCase          |IncGeo_WardCode|I
Home Station        |1        |Initial      |Initial Mobilisation|NULL       |NULL                 |000008-01012023|2023-01-01|2023   |2025-06-12 00:07:49|0         |Special Service|Special Service    |Other rescue/release of persons|Dwelling         |Purpose Built Flats/Maisonettes - 4 to 9 storeys |Correct incident location           |NULL         |SW18             |0.0          |22902216.0|E09000032         |WANDSWORTH          |Wandsworth          |E05014028      |WANDSWORTH TOWN  |WANDSWORTH TOWN   |NULL     |NULL      |525450         |174650          |nan        |nan         |London|Wandsworth           |355                             |Battersea                            |NULL                             |NULL                                  |1                            |1                |1        |60                |364         |1       |
# |000008             |000008-01012018|2018   |NULL       |NULL       |0         |5055153               |A392         |1                   |2018-01-01 00:04:00 |2018-01-01 00:05:00|2018-01-01 00:10:00|73                |275              |348                  |2018-01-01 00:16:00|NULL               |A39                     |Finchley                |Home Station        |1        |Initial      |Initial Mobilisation|NULL       |NULL                 |000008-01012025|2025-01-01|2025   |2025-06-12 00:05:53|0         |Fire           |Secondary Fire     |NULL                           |Outdoor Structure|Small refuse/rubbish container                   |In street outside gazetteer location|NW10 5NY     |NW10             |202191328.0  |20201241.0|E09000005         |BRENT               |Brent               |E05013507      |QUEENS PARK      |QUEENS PARK       |522726   |182879    |522750         |182850          |51.53149335|-0.23207619 |London|North Kensington     |2                               |Wembley                              |NULL                             |NULL                                  |1                            |1                |1        |60                |430         |1       |
# +-------------------+---------------+-------+-----------+-----------+----------+----------------------+-------------+--------------------+--------------------+-------------------+-------------------+------------------+-----------------+---------------------+-------------------+-------------------+------------------------+------------------------+--------------------+---------+-------------+--------------------+-----------+---------------------+---------------+----------+-------+-------------------+----------+---------------+-------------------+-------------------------------+-----------------+-------------------------------------------------+------------------------------------+-------------+-----------------+-------------+----------+------------------+--------------------+--------------------+---------------+-----------------+------------------+---------+----------+---------------+----------------+-----------+------------+------+---------------------+--------------------------------+-------------------------------------+---------------------------------+--------------------------------------+-----------------------------+-----------------+---------+------------------+------------+--------+
# only showing top 20 rows

# %%
print(df_joined.dtypes)
# Out:
# [('incident_id_cleaned', 'string'), ('IncidentNumber', 'string'), ('CalYear', 'int'), ('BoroughName', 'string'), ('WardName', 'string'), ('HourOfCall', 'int'), ('ResourceMobilisationId', 'int'), ('Resource_Code', 'string'), ('PerformanceReporting', 'string'), ('DateAndTimeMobilised', 'timestamp'), ('DateAndTimeMobile', 'timestamp'), ('DateAndTimeArrived', 'timestamp'), ('TurnoutTimeSeconds', 'int'), ('TravelTimeSeconds', 'int'), ('AttendanceTimeSeconds', 'int'), ('DateAndTimeLeft', 'timestamp'), ('DateAndTimeReturned', 'timestamp'), ('DeployedFromStation_Code', 'string'), ('DeployedFromStation_Name', 'string'), ('DeployedFromLocation', 'string'), ('PumpOrder', 'int'), ('PlusCode_Code', 'string'), ('PlusCode_Description', 'string'), ('DelayCodeId', 'int'), ('DelayCode_Description', 'string'), ('IncidentNumber', 'string'), ('DateOfCall', 'date'), ('CalYear', 'int'), ('TimeOfCall', 'timestamp'), ('HourOfCall', 'int'), ('IncidentGroup', 'string'), ('StopCodeDescription', 'string'), ('SpecialServiceType', 'string'), ('PropertyCategory', 'string'), ('PropertyType', 'string'), ('AddressQualifier', 'string'), ('Postcode_full', 'string'), ('Postcode_district', 'string'), ('UPRN', 'string'), ('USRN', 'string'), ('IncGeo_BoroughCode', 'string'), ('IncGeo_BoroughName', 'string'), ('ProperCase', 'string'), ('IncGeo_WardCode', 'string'), ('IncGeo_WardName', 'string'), ('IncGeo_WardNameNew', 'string'), ('Easting_m', 'int'), ('Northing_m', 'int'), ('Easting_rounded', 'int'), ('Northing_rounded', 'int'), ('Latitude', 'string'), ('Longitude', 'string'), ('FRS', 'string'), ('IncidentStationGround', 'string'), ('FirstPumpArriving_AttendanceTime', 'int'), ('FirstPumpArriving_DeployedFromStation', 'string'), ('SecondPumpArriving_AttendanceTime', 'int'), ('SecondPumpArriving_DeployedFromStation', 'string'), ('NumStationsWithPumpsAttending', 'int'), ('NumPumpsAttending', 'int'), ('PumpCount', 'int'), ('PumpMinutesRounded', 'int'), ('NotionalCost', 'int'), ('NumCalls', 'int')]

# %%
colonnes_apres_jointure = df_joined.columns
nombre_colonnes = len(colonnes_apres_jointure)

print("Liste des colonnes après jointure :")
print(colonnes_apres_jointure)
print(f"Nombre total de colonnes : {nombre_colonnes}")
# Out:
# Liste des colonnes après jointure :
# ['incident_id_cleaned', 'IncidentNumber', 'CalYear', 'BoroughName', 'WardName', 'HourOfCall', 'ResourceMobilisationId', 'Resource_Code', 'PerformanceReporting', 'DateAndTimeMobilised', 'DateAndTimeMobile', 'DateAndTimeArrived', 'TurnoutTimeSeconds', 'TravelTimeSeconds', 'AttendanceTimeSeconds', 'DateAndTimeLeft', 'DateAndTimeReturned', 'DeployedFromStation_Code', 'DeployedFromStation_Name', 'DeployedFromLocation', 'PumpOrder', 'PlusCode_Code', 'PlusCode_Description', 'DelayCodeId', 'DelayCode_Description', 'IncidentNumber', 'DateOfCall', 'CalYear', 'TimeOfCall', 'HourOfCall', 'IncidentGroup', 'StopCodeDescription', 'SpecialServiceType', 'PropertyCategory', 'PropertyType', 'AddressQualifier', 'Postcode_full', 'Postcode_district', 'UPRN', 'USRN', 'IncGeo_BoroughCode', 'IncGeo_BoroughName', 'ProperCase', 'IncGeo_WardCode', 'IncGeo_WardName', 'IncGeo_WardNameNew', 'Easting_m', 'Northing_m', 'Easting_rounded', 'Northing_rounded', 'Latitude', 'Longitude', 'FRS', 'IncidentStationGround', 'FirstPumpArriving_AttendanceTime', 'FirstPumpArriving_DeployedFromStation', 'SecondPumpArriving_AttendanceTime', 'SecondPumpArriving_DeployedFromStation', 'NumStationsWithPumpsAttending', 'NumPumpsAttending', 'PumpCount', 'PumpMinutesRounded', 'NotionalCost', 'NumCalls']
# Nombre total de colonnes : 64

# %%
# Étape 1 : Lister les colonnes des deux DataFrames
cols_incidents = set(df_incidents_cleaned.columns)
cols_mobilisations = set(df_mobilisations_cleaned.columns)

# Étape 2 : Trouver les colonnes communes
common_columns = cols_incidents.intersection(cols_mobilisations)

# Étape 3 : Afficher
print("Colonnes présentes dans les deux DataFrames (possibles doublons après jointure) :")
for col_name in sorted(common_columns):
    print(f"- {col_name}")

print(f"\nNombre de colonnes communes : {len(common_columns)}")
# Out:
# Colonnes présentes dans les deux DataFrames (possibles doublons après jointure) :
# - CalYear
# - HourOfCall
# - IncidentNumber
# - incident_id_cleaned
#
# Nombre de colonnes communes : 4

# %%
from pyspark.sql.functions import col, when

# Comparaison CalYear
df_joined.select(
    (col("CalYear") == col("df_incidents_cleaned.CalYear")).alias("same_CalYear")
).groupBy("same_CalYear").count().show()

# Comparaison HourOfCall
df_joined.select(
    (col("HourOfCall") == col("df_incidents_cleaned.HourOfCall")).alias("same_HourOfCall")
).groupBy("same_HourOfCall").count().show()

# Comparaison IncidentNumber
df_joined.select(
    (col("IncidentNumber") == col("df_incidents_cleaned.IncidentNumber")).alias("same_IncidentNumber")
).groupBy("same_IncidentNumber").count().show()
# Out:
# {"ts": "2025-06-12 04:57:56.823", "level": "ERROR", "logger": "DataFrameQueryContextLogger", "msg": "[AMBIGUOUS_REFERENCE] Reference `CalYear` is ambiguous, could be: [`CalYear`, `CalYear`]. SQLSTATE: 42704", "context": {"file": "line 5 in cell [54]", "line": "", "fragment": "col", "errorClass": "AMBIGUOUS_REFERENCE"}, "exception": {"class": "Py4JJavaError", "msg": "An error occurred while calling o834.select.\n: org.apache.spark.sql.AnalysisException: [AMBIGUOUS_REFERENCE] Reference `CalYear` is ambiguous, could be: [`CalYear`, `CalYear`]. SQLSTATE: 42704\r\n\tat org.apache.spark.sql.errors.QueryCompilationErrors$.ambiguousReferenceError(QueryCompilationErrors.scala:2163)\r\n\tat org.apache.spark.sql.catalyst.expressions.package$AttributeSeq.resolve(package.scala:356)\r\n\tat org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.resolveChildren(LogicalPlan.scala:164)\r\n\tat org.apache.spark.sql.catalyst.analysis.ColumnResolutionHelper.$anonfun$resolveExpressionByPlanChildren$1(ColumnResolutionHelper.scala:520)\r\n\tat org.apache.spark.sql.catalyst.analysis.ColumnResolutionHelper.$anonfun$resolveExpression$3(ColumnResolutionHelper.scala:172)\r\n\tat org.apache.spark.sql.catalyst.analysis.package$.withPosition(package.scala:104)\r\n\tat org.apache.spark.sql.catalyst.analysis.ColumnResolutionHelper.$anonfun$resolveExpression$1(ColumnResolutionHelper.scala:179)\r\n\tat org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(origin.scala:86)\r\n\tat org.apache.spark.sql.catalyst.analysis.ColumnResolutionHelper.innerResolve$1(ColumnResolutionHelper.scala:145)\r\n\tat org.apache.spark.sql.catalyst.analysis.ColumnResolutionHelper.$anonfun$resolveExpression$9(ColumnResolutionHelper.scala:202)\r\n\tat scala.collection.immutable.ArraySeq.map(ArraySeq.scala:75)\r\n\tat scala.collection.immutable.ArraySeq.map(ArraySeq.scala:35)\r\n\tat org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:708)\r\n\tat org.apache.spark.sql.catalyst.analysis.ColumnResolutionHelper.$anonfun$resolveExpression$1(ColumnResolutionHelper.scala:202)\r\n\tat org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(origin.scala:86)\r\n\tat org.apache.spark.sql.catalyst.analysis.ColumnResolutionHelper.innerResolve$1(ColumnResolutionHelper.scala:145)\r\n\tat org.apache.spark.sql.catalyst.analysis.ColumnResolutionHelper.$anonfun$resolveExpression$9(ColumnResolutionHelper.scala:202)\r\n\tat org.apache.spark.sql.catalyst.trees.UnaryLike.mapChildren(TreeNode.scala:1231)\r\n\tat org.apache.spark.sql.catalyst.trees.UnaryLike.mapChildren$(TreeNode.scala:1230)\r\n\tat org.apache.spark.sql.catalyst.expressions.UnaryExpression.mapChildren(Expression.scala:563)\r\n\tat org.apache.spark.sql.catalyst.analysis.ColumnResolutionHelper.$anonfun$resolveExpression$1(ColumnResolutionHelper.scala:202)\r\n\tat org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(origin.scala:86)\r\n\tat org.apache.spark.sql.catalyst.analysis.ColumnResolutionHelper.innerResolve$1(ColumnResolutionHelper.scala:145)\r\n\tat org.apache.spark.sql.catalyst.analysis.ColumnResolutionHelper.resolveExpression(ColumnResolutionHelper.scala:209)\r\n\tat org.apache.spark.sql.catalyst.analysis.ColumnResolutionHelper.resolveExpressionByPlanChildren(ColumnResolutionHelper.scala:527)\r\n\tat org.apache.spark.sql.catalyst.analysis.ColumnResolutionHelper.resolveExpressionByPlanChildren$(ColumnResolutionHelper.scala:513)\r\n\tat org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveReferences.resolveExpressionByPlanChildren(Analyzer.scala:1400)\r\n\tat org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveReferences$$anonfun$apply$14.$anonfun$applyOrElse$107(Analyzer.scala:1566)\r\n\tat scala.collection.immutable.List.map(List.scala:247)\r\n\tat scala.collection.immutable.List.map(List.scala:79)\r\n\tat org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveReferences$$anonfun$apply$14.applyOrElse(Analyzer.scala:1566)\r\n\tat org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRefer ...
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[54], line 4
#       1 from pyspark.sql.functions import col, when
#       3 # Comparaison CalYear
# ----> 4 df_joined.select(
#       5     (col("CalYear") == col("df_incidents_cleaned.CalYear")).alias("same_CalYear")
#       6 ).groupBy("same_CalYear").count().show()
#       8 # Comparaison HourOfCall
#       9 df_joined.select(
#      10     (col("HourOfCall") == col("df_incidents_cleaned.HourOfCall")).alias("same_HourOfCall")
#      11 ).groupBy("same_HourOfCall").count().show()
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pyspark\sql\classic\dataframe.py:991, in DataFrame.select(self, *cols)
#     990 def select(self, *cols: "ColumnOrName") -> ParentDataFrame:  # type: ignore[misc]
# --> 991     jdf = self._jdf.select(self._jcols(*cols))
#     992     return DataFrame(jdf, self.sparkSession)
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\py4j\java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
#    1361 answer = self.gateway_client.send_command(command)
# -> 1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#    1366     if hasattr(temp_arg, "_detach"):
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pyspark\errors\exceptions\captured.py:288, in capture_sql_exception.<locals>.deco(*a, **kw)
#     284 converted = convert_exception(e.java_exception)
#     285 if not isinstance(converted, UnknownException):
#     286     # Hide where the exception came from that shows a non-Pythonic
#     287     # JVM exception message.
# --> 288     raise converted from None
#     289 else:
#     290     raise
#
# AnalysisException: [AMBIGUOUS_REFERENCE] Reference `CalYear` is ambiguous, could be: [`CalYear`, `CalYear`]. SQLSTATE: 42704

# %%
from pyspark.sql.functions import min, max

periode = df_joined.agg(
    min("CalYear_mob").alias("Annee_min"),
    max("CalYear_mob").alias("Annee_max")
).collect()[0]

print(f"Période des données : de {periode['Annee_min']} à {periode['Annee_max']}")
# Out:
# {"ts": "2025-06-12 04:58:02.865", "level": "ERROR", "logger": "DataFrameQueryContextLogger", "msg": "[UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `CalYear_mob` cannot be resolved. Did you mean one of the following? [`CalYear`, `CalYear`, `Easting_m`, `WardName`, `NumCalls`]. SQLSTATE: 42703", "context": {"file": "jdk.internal.reflect.GeneratedMethodAccessor56.invoke(Unknown Source)", "line": "", "fragment": "col", "errorClass": "UNRESOLVED_COLUMN.WITH_SUGGESTION"}, "exception": {"class": "Py4JJavaError", "msg": "An error occurred while calling o874.agg.\n: org.apache.spark.sql.AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `CalYear_mob` cannot be resolved. Did you mean one of the following? [`CalYear`, `CalYear`, `Easting_m`, `WardName`, `NumCalls`]. SQLSTATE: 42703;\n'Aggregate ['min('CalYear_mob) AS Annee_min#5509, 'max('CalYear_mob) AS Annee_max#5510]\n+- Project [incident_id_cleaned#5048, IncidentNumber#4726, CalYear#4727, BoroughName#4728, WardName#4729, HourOfCall#4730, ResourceMobilisationId#4731, Resource_Code#4732, PerformanceReporting#4733, DateAndTimeMobilised#4734, DateAndTimeMobile#4735, DateAndTimeArrived#4736, TurnoutTimeSeconds#4737, TravelTimeSeconds#4738, AttendanceTimeSeconds#4739, DateAndTimeLeft#4740, DateAndTimeReturned#4741, DeployedFromStation_Code#4742, DeployedFromStation_Name#4743, DeployedFromLocation#4744, PumpOrder#4745, PlusCode_Code#4746, PlusCode_Description#4747, DelayCodeId#4748, DelayCode_Description#4749, ... 39 more fields]\n   +- Join Inner, (incident_id_cleaned#5048 = incident_id_cleaned#5047)\n      :- Project [IncidentNumber#4726, CalYear#4727, BoroughName#4728, WardName#4729, HourOfCall#4730, ResourceMobilisationId#4731, Resource_Code#4732, PerformanceReporting#4733, DateAndTimeMobilised#4734, DateAndTimeMobile#4735, DateAndTimeArrived#4736, TurnoutTimeSeconds#4737, TravelTimeSeconds#4738, AttendanceTimeSeconds#4739, DateAndTimeLeft#4740, DateAndTimeReturned#4741, DeployedFromStation_Code#4742, DeployedFromStation_Name#4743, DeployedFromLocation#4744, PumpOrder#4745, PlusCode_Code#4746, PlusCode_Description#4747, DelayCodeId#4748, DelayCode_Description#4749, CASE WHEN Contains(IncidentNumber#4726, .) THEN regexp_extract(IncidentNumber#4726, ^([^\\.]+), 1) WHEN Contains(IncidentNumber#4726, -) THEN regexp_extract(IncidentNumber#4726, ^([^-]+), 1) ELSE IncidentNumber#4726 END AS incident_id_cleaned#5048]\n      :  +- Relation [IncidentNumber#4726,CalYear#4727,BoroughName#4728,WardName#4729,HourOfCall#4730,ResourceMobilisationId#4731,Resource_Code#4732,PerformanceReporting#4733,DateAndTimeMobilised#4734,DateAndTimeMobile#4735,DateAndTimeArrived#4736,TurnoutTimeSeconds#4737,TravelTimeSeconds#4738,AttendanceTimeSeconds#4739,DateAndTimeLeft#4740,DateAndTimeReturned#4741,DeployedFromStation_Code#4742,DeployedFromStation_Name#4743,DeployedFromLocation#4744,PumpOrder#4745,PlusCode_Code#4746,PlusCode_Description#4747,DelayCodeId#4748,DelayCode_Description#4749] csv\n      +- Project [IncidentNumber#4670, DateOfCall#4671, CalYear#4672, TimeOfCall#4673, HourOfCall#4674, IncidentGroup#4675, StopCodeDescription#4676, SpecialServiceType#4677, PropertyCategory#4678, PropertyType#4679, AddressQualifier#4680, Postcode_full#4681, Postcode_district#4682, UPRN#4683, USRN#4684, IncGeo_BoroughCode#4685, IncGeo_BoroughName#4686, ProperCase#4687, IncGeo_WardCode#4688, IncGeo_WardName#4689, IncGeo_WardNameNew#4690, Easting_m#4691, Northing_m#4692, Easting_rounded#4693, Northing_rounded#4694, ... 15 more fields]\n         +- Relation [IncidentNumber#4670,DateOfCall#4671,CalYear#4672,TimeOfCall#4673,HourOfCall#4674,IncidentGroup#4675,StopCodeDescription#4676,SpecialServiceType#4677,PropertyCategory#4678,PropertyType#4679,AddressQualifier#4680,Postcode_full#4681,Postcode_district#4682,UPRN#4683,USRN#4684,IncGeo_BoroughCode#4685,IncGeo_BoroughName#4686,ProperCase#4687,IncGeo_WardCode#4688,IncGeo_WardName#4689,Inc ...
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[55], line 3
#       1 from pyspark.sql.functions import min, max
# ----> 3 periode = df_joined.agg(
#       4     min("CalYear_mob").alias("Annee_min"),
#       5     max("CalYear_mob").alias("Annee_max")
#       6 ).collect()[0]
#       8 print(f"Période des données : de {periode['Annee_min']} à {periode['Annee_max']}")
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pyspark\sql\classic\dataframe.py:1109, in DataFrame.agg(self, *exprs)
#    1108 def agg(self, *exprs: Union[Column, Dict[str, str]]) -> ParentDataFrame:
# -> 1109     return self.groupBy().agg(*exprs)
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pyspark\sql\group.py:190, in GroupedData.agg(self, *exprs)
#     188     assert all(isinstance(c, Column) for c in exprs), "all exprs should be Column"
#     189     exprs = cast(Tuple[Column, ...], exprs)
# --> 190     jdf = self._jgd.agg(exprs[0]._jc, _to_seq(self.session._sc, [c._jc for c in exprs[1:]]))
#     191 return DataFrame(jdf, self.session)
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\py4j\java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
#    1361 answer = self.gateway_client.send_command(command)
# -> 1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#    1366     if hasattr(temp_arg, "_detach"):
#
# File c:\Users\9609241C\london-fire-response\.venv\Lib\site-packages\pyspark\errors\exceptions\captured.py:288, in capture_sql_exception.<locals>.deco(*a, **kw)
#     284 converted = convert_exception(e.java_exception)
#     285 if not isinstance(converted, UnknownException):
#     286     # Hide where the exception came from that shows a non-Pythonic
#     287     # JVM exception message.
# --> 288     raise converted from None
#     289 else:
#     290     raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `CalYear_mob` cannot be resolved. Did you mean one of the following? [`CalYear`, `CalYear`, `Easting_m`, `WardName`, `NumCalls`]. SQLSTATE: 42703;
# 'Aggregate ['min('CalYear_mob) AS Annee_min#5509, 'max('CalYear_mob) AS Annee_max#5510]
# +- Project [incident_id_cleaned#5048, IncidentNumber#4726, CalYear#4727, BoroughName#4728, WardName#4729, HourOfCall#4730, ResourceMobilisationId#4731, Resource_Code#4732, PerformanceReporting#4733, DateAndTimeMobilised#4734, DateAndTimeMobile#4735, DateAndTimeArrived#4736, TurnoutTimeSeconds#4737, TravelTimeSeconds#4738, AttendanceTimeSeconds#4739, DateAndTimeLeft#4740, DateAndTimeReturned#4741, DeployedFromStation_Code#4742, DeployedFromStation_Name#4743, DeployedFromLocation#4744, PumpOrder#4745, PlusCode_Code#4746, PlusCode_Description#4747, DelayCodeId#4748, DelayCode_Description#4749, ... 39 more fields]
#    +- Join Inner, (incident_id_cleaned#5048 = incident_id_cleaned#5047)
#       :- Project [IncidentNumber#4726, CalYear#4727, BoroughName#4728, WardName#4729, HourOfCall#4730, ResourceMobilisationId#4731, Resource_Code#4732, PerformanceReporting#4733, DateAndTimeMobilised#4734, DateAndTimeMobile#4735, DateAndTimeArrived#4736, TurnoutTimeSeconds#4737, TravelTimeSeconds#4738, AttendanceTimeSeconds#4739, DateAndTimeLeft#4740, DateAndTimeReturned#4741, DeployedFromStation_Code#4742, DeployedFromStation_Name#4743, DeployedFromLocation#4744, PumpOrder#4745, PlusCode_Code#4746, PlusCode_Description#4747, DelayCodeId#4748, DelayCode_Description#4749, CASE WHEN Contains(IncidentNumber#4726, .) THEN regexp_extract(IncidentNumber#4726, ^([^\.]+), 1) WHEN Contains(IncidentNumber#4726, -) THEN regexp_extract(IncidentNumber#4726, ^([^-]+), 1) ELSE IncidentNumber#4726 END AS incident_id_cleaned#5048]
#       :  +- Relation [IncidentNumber#4726,CalYear#4727,BoroughName#4728,WardName#4729,HourOfCall#4730,ResourceMobilisationId#4731,Resource_Code#4732,PerformanceReporting#4733,DateAndTimeMobilised#4734,DateAndTimeMobile#4735,DateAndTimeArrived#4736,TurnoutTimeSeconds#4737,TravelTimeSeconds#4738,AttendanceTimeSeconds#4739,DateAndTimeLeft#4740,DateAndTimeReturned#4741,DeployedFromStation_Code#4742,DeployedFromStation_Name#4743,DeployedFromLocation#4744,PumpOrder#4745,PlusCode_Code#4746,PlusCode_Description#4747,DelayCodeId#4748,DelayCode_Description#4749] csv
#       +- Project [IncidentNumber#4670, DateOfCall#4671, CalYear#4672, TimeOfCall#4673, HourOfCall#4674, IncidentGroup#4675, StopCodeDescription#4676, SpecialServiceType#4677, PropertyCategory#4678, PropertyType#4679, AddressQualifier#4680, Postcode_full#4681, Postcode_district#4682, UPRN#4683, USRN#4684, IncGeo_BoroughCode#4685, IncGeo_BoroughName#4686, ProperCase#4687, IncGeo_WardCode#4688, IncGeo_WardName#4689, IncGeo_WardNameNew#4690, Easting_m#4691, Northing_m#4692, Easting_rounded#4693, Northing_rounded#4694, ... 15 more fields]
#          +- Relation [IncidentNumber#4670,DateOfCall#4671,CalYear#4672,TimeOfCall#4673,HourOfCall#4674,IncidentGroup#4675,StopCodeDescription#4676,SpecialServiceType#4677,PropertyCategory#4678,PropertyType#4679,AddressQualifier#4680,Postcode_full#4681,Postcode_district#4682,UPRN#4683,USRN#4684,IncGeo_BoroughCode#4685,IncGeo_BoroughName#4686,ProperCase#4687,IncGeo_WardCode#4688,IncGeo_WardName#4689,IncGeo_WardNameNew#4690,Easting_m#4691,Northing_m#4692,Easting_rounded#4693,Northing_rounded#4694,... 14 more fields] csv

# %%
from pyspark.sql.functions import min, max

periode = df_joined.agg(
    min("CalYear_inc").alias("Annee_min"),
    max("CalYear_inc").alias("Annee_max")
).collect()[0]

print(f"Période des données : de {periode['Annee_min']} à {periode['Annee_max']}")
# Out:
# Période des données : de 2009 à 2025
